# %%
s="..."
A=0;
T=0;
G=0
C=0
for i in s:
    if i=="A":
        A+=1
    if i=="C":
        C+=1
    if i=="T":
        T+=1
    if i=="G":
        G+=1
    
print(A)        
print(C)
print(G)
print(T)
# Out:
# 224
# 225
# 224
# 213

# %%
 def qt(s):
        return s.count("A"), s.count("G"), s.count("C"), s.count("T")

# %%
print(qt(s))
# Out:
# (224, 224, 225, 213)

# %%
print(*map(input().count, "ACGT"))
# Out:
# ...
# 224 225 224 213
